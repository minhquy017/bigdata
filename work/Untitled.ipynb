# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("test").getOrCreate()

data = [("Hue", 100), ("Da Nang", 200), ("HCM", 300)]
df = spark.createDataFrame(data, ["city", "value"])

df.show()
# Out:
# +-------+-----+
# |   city|value|
# +-------+-----+
# |    Hue|  100|
# |Da Nang|  200|
# |    HCM|  300|
# +-------+-----+
