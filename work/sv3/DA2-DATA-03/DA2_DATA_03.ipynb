# %%
# =========================================
# IMPORT LIBRARIES
# =========================================

from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.window import Window

import boto3
from botocore.client import Config

# %%
# =========================================
# INIT SPARK SESSION
# =========================================

spark = SparkSession.builder \
    .appName("SV3_Crypto_ETL") \
    .getOrCreate()

print("Spark Started Successfully")

# =========================================
# MINIO S3A CONFIG
# =========================================

hadoop_conf = spark.sparkContext._jsc.hadoopConfiguration()

hadoop_conf.set("fs.s3a.endpoint", "http://minio:9000")
hadoop_conf.set("fs.s3a.access.key", "admin")
hadoop_conf.set("fs.s3a.secret.key", "password123")
hadoop_conf.set("fs.s3a.path.style.access", "true")
hadoop_conf.set("fs.s3a.connection.ssl.enabled", "false")

hadoop_conf.set(
    "fs.s3a.aws.credentials.provider",
    "org.apache.hadoop.fs.s3a.SimpleAWSCredentialsProvider"
)

print("MinIO Configuration Completed")
# Out:
# Spark Started Successfully
# MinIO Configuration Completed

# %%
# =========================================
# LOAD RAW DATA FROM MINIO
# =========================================

df = spark.read.csv(
    "s3a://crypto-raw-data/bitcoin_1m.csv",
    "s3a://crypto-raw-data/altcoins_500d.csv",
    header=True,
    inferSchema=True
)

print("Raw Dataset Loaded")

print("Total Rows:", df.count())

df.show(20)

df.printSchema()
# Out:
# ---------------------------------------------------------------------------
# ParseException                            Traceback (most recent call last)
# Cell In[6], line 5
#       1 # =========================================
#       2 # LOAD RAW DATA FROM MINIO
#       3 # =========================================
#       4
# ----> 5 df = spark.read.csv(
#       6     "s3a://crypto-raw-data/bitcoin_1m.csv",
#       7     "s3a://crypto-raw-data/altcoins_500d.csv",
#       8     header=True,
#
# File /usr/local/spark/python/pyspark/sql/readwriter.py:799, in DataFrameReader.csv(self, path, schema, sep, encoding, quote, escape, comment, header, inferSchema, ignoreLeadingWhiteSpace, ignoreTrailingWhiteSpace, nullValue, nanValue, positiveInf, negativeInf, dateFormat, timestampFormat, maxColumns, maxCharsPerColumn, maxMalformedLogPerPartition, mode, columnNameOfCorruptRecord, multiLine, charToEscapeQuoteEscaping, samplingRatio, enforceSchema, emptyValue, locale, lineSep, pathGlobFilter, recursiveFileLookup, modifiedBefore, modifiedAfter, unescapedQuoteHandling)
#     715 def csv(
#     716     self,
#     717     path: PathOrPaths,
#    (...)    750     unescapedQuoteHandling: Optional[str] = None,
#     751 ) -> "DataFrame":
#     752     r"""Loads a CSV file and returns the result as a  :class:`DataFrame`.
#     753
#     754     This function will go through the input once to determine the input schema if
#    (...)    797     +---+----+
#     798     """
# --> 799     self._set_opts(
#     800         schema=schema,
#     801         sep=sep,
#     802         encoding=encoding,
#     803         quote=quote,
#     804         escape=escape,
#     805         comment=comment,
#     806         header=header,
#     807         inferSchema=inferSchema,
#     808         ignoreLeadingWhiteSpace=ignoreLeadingWhiteSpace,
#     809         ignoreTrailingWhiteSpace=ignoreTrailingWhiteSpace,
#     810         nullValue=nullValue,
#     811         nanValue=nanValue,
#     812         positiveInf=positiveInf,
#     813         negativeInf=negativeInf,
#     814         dateFormat=dateFormat,
#     815         timestampFormat=timestampFormat,
#     816         maxColumns=maxColumns,
#     817         maxCharsPerColumn=maxCharsPerColumn,
#     818         maxMalformedLogPerPartition=maxMalformedLogPerPartition,
#     819         mode=mode,
#     820         columnNameOfCorruptRecord=columnNameOfCorruptRecord,
#     821         multiLine=multiLine,
#     822         charToEscapeQuoteEscaping=charToEscapeQuoteEscaping,
#     823         samplingRatio=samplingRatio,
#     824         enforceSchema=enforceSchema,
#     825         emptyValue=emptyValue,
#     826         locale=locale,
#     827         lineSep=lineSep,
#     828         pathGlobFilter=pathGlobFilter,
#     829         recursiveFileLookup=recursiveFileLookup,
#     830         modifiedBefore=modifiedBefore,
#     831         modifiedAfter=modifiedAfter,
#     832         unescapedQuoteHandling=unescapedQuoteHandling,
#     833     )
#     834     if isinstance(path, str):
#     835         path = [path]
#
# File /usr/local/spark/python/pyspark/sql/readwriter.py:50, in OptionUtils._set_opts(self, schema, **options)
#      46 """
#      47 Set named options (filter out those the value is None)
#      48 """
#      49 if schema is not None:
# ---> 50     self.schema(schema)  # type: ignore[attr-defined]
#      51 for k, v in options.items():
#      52     if v is not None:
#
# File /usr/local/spark/python/pyspark/sql/readwriter.py:154, in DataFrameReader.schema(self, schema)
#     152     self._jreader = self._jreader.schema(jschema)
#     153 elif isinstance(schema, str):
# --> 154     self._jreader = self._jreader.schema(schema)
#     155 else:
#     156     raise PySparkTypeError(
#     157         errorClass="NOT_STR_OR_STRUCT",
#     158         messageParameters={
#    (...)    161         },
#     162     )
#
# File /usr/local/spark/python/lib/py4j-0.10.9.9-src.zip/py4j/java_gateway.py:1362, in JavaMember.__call__(self, *args)
#    1358             args_command +\
#    1359             proto.END_COMMAND_PART
#    1360
#    1361         answer = self.gateway_client.send_command(command)
# -> 1362         return_value = get_return_value(
#    1363             answer, self.gateway_client, self.target_id, self.name)
#    1364
#    1365         for temp_arg in temp_args:
#
# File /usr/local/spark/python/pyspark/errors/exceptions/captured.py:269, in capture_sql_exception.<locals>.deco(*a, **kw)
#     265 converted = convert_exception(e.java_exception)
#     266 if not isinstance(converted, UnknownException):
#     267     # Hide where the exception came from that shows a non-Pythonic
#     268     # JVM exception message.
# --> 269     raise converted from None
#     270 else:
#     271     raise
#
# ParseException:
# [PARSE_SYNTAX_ERROR] Syntax error at or near ':'. SQLSTATE: 42601 (line 1, pos 3)
#
# == SQL ==
# s3a://crypto-raw-data/altcoins_500d.csv
# ---^^^
